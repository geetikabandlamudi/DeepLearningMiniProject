# %% [markdown]
# # ResNet

# %% [markdown]
# In this problem, you are asked to train a deep convolutional neural network to perform image classification. In this mini-project you are tasked with coming up with a modified residual network (ResNet) architecture with the highest test accuracy on the CIFAR10 image classification dataset, under the constraint that your model has no more than 5 million parameters.
#
# We will train ResNet using the CIFAR10 dataset, which consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. The classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck.
#
# ![](https://storage.googleapis.com/kaggle-competitions/kaggle/3649/media/cifar-10.png)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import _LRScheduler
import torch.utils.data as data
from torchsummary import summary

import torchvision.transforms as transforms
import torchvision.datasets as datasets

from sklearn import decomposition
from sklearn import manifold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

import copy
import random
import time
import torch.backends.cudnn as cudnn

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
cudnn.deterministic = True

# %% [markdown]
# # Loading and Preparing the Data
# Our dataset is made up of color images but three color channels (red, green and blue), compared to MNIST's black and white images with a single color channel. To normalize our data we need to calculate the means and standard deviations for each of the color channels independently, and normalize them.

# %%
ROOT = '.data'
train_data = datasets.CIFAR10(root = ROOT, 
                              train = True, 
                              download = True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to .data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 48849741.24it/s]
# Extracting .data/cifar-10-python.tar.gz to .data

# %%
# Compute means and standard deviations along the R,G,B channel

means = train_data.data.mean(axis = (0,1,2)) / 255
stds = train_data.data.std(axis = (0,1,2)) / 255

# %% [markdown]
# Next, we will do data augmentation. For each training image we will randomly rotate it (by up to 5 degrees), flip/mirror with probability 0.5, shift by +/-1 pixel. Finally we will normalize each color channel using the means/stds we calculated above.

# %%
train_transforms = transforms.Compose([
                           transforms.RandomRotation(15),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(32, padding = 4),
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, 
                                                std = stds)
                       ])

test_transforms = transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize(mean = means, 
                                                std = stds)
                       ])

# %% [markdown]
# Next, we'll load the dataset along with the transforms defined above.
#
# We will also create a validation set with 10% of the training samples. The validation set will be used to monitor loss along different epochs, and we will pick the model along the optimization path that performed the best, and report final test accuracy numbers using this model.

# %%
train_data = datasets.CIFAR10(ROOT, 
                              train = True, 
                              download = True, 
                              transform = train_transforms)

test_data = datasets.CIFAR10(ROOT, 
                             train = False, 
                             download = True, 
                             transform = test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
VALID_RATIO = 0.9

n_train_examples = int(len(train_data) * VALID_RATIO)
n_valid_examples = len(train_data) - n_train_examples

train_data, valid_data = data.random_split(train_data, 
                                           [n_train_examples, n_valid_examples])

# %%
valid_data = copy.deepcopy(valid_data)
valid_data.dataset.transform = test_transforms

# %% [markdown]
# # Plotting
#
# Now, we'll create a function to plot some of the images in our dataset to see what they actually look like.
#
# Note that by default PyTorch handles images that are arranged [channel, height, width], but matplotlib expects images to be [height, width, channel], hence we need to permute the dimensions of our images before plotting them.

# %%
def plot_images(images, labels, classes, normalize = False):

    n_images = len(images)

    rows = int(np.sqrt(n_images))
    cols = int(np.sqrt(n_images))

    fig = plt.figure(figsize = (10, 10))

    for i in range(rows*cols):

        ax = fig.add_subplot(rows, cols, i+1)
        
        image = images[i]

        if normalize:
            image_min = image.min()
            image_max = image.max()
            image.clamp_(min = image_min, max = image_max)
            image.add_(-image_min).div_(image_max - image_min + 1e-5)

        ax.imshow(image.permute(1, 2, 0).cpu().numpy())
        ax.set_title(classes[labels[i]])
        ax.axis('off')

# %% [markdown]
# One point here: matplotlib is expecting the values of every pixel to be between  [0,1] , however our normalization will cause them to be outside this range. By default matplotlib will then clip these values into the  [0,1]  range. This clipping causes all of the images to look a bit weird - all of the colors are oversaturated. The solution is to normalize each image between [0,1].

# %%
N_IMAGES = 25

images, labels = zip(*[(image, label) for image, label in 
                           [train_data[i] for i in range(N_IMAGES)]])

classes = test_data.classes

# %%
plot_images(images, labels, classes, normalize = True)

# %% [markdown]
# The final bit of the data processing is creating the iterators. We will use a large. Generally, a larger batch size means that our model trains faster but is a bit more susceptible to overfitting.

# %%
BATCH_SIZE = 128

train_iterator = torch.utils.data.DataLoader(train_data, 
                                          batch_size=BATCH_SIZE, 
                                          shuffle=True, 
                                          num_workers=1)

valid_iterator = torch.utils.data.DataLoader(valid_data, 
                                          batch_size=BATCH_SIZE, 
                                          shuffle=True, 
                                          num_workers=1)

test_iterator = torch.utils.data.DataLoader(test_data, 
                                          batch_size=BATCH_SIZE, 
                                          shuffle=False, 
                                          num_workers=1)

# %% [markdown]
# # Defining the Model

# %%
class ResNet(nn.Module):
    def __init__(self):
        super(ResNet, self).__init__()
        
        self.conv = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        self.layer1 = self.make_layer(64, 64, 64, 2, stride=1)
        self.layer2 = self.make_layer(64, 156, 156, 2, stride=2)
        self.layer3 = self.make_layer(156, 220, 220, 2, stride=2)
        
        self.fc = nn.Linear(220, 10)
        
    def make_layer(self, in_channels, mid_channels, out_channels, num_blocks, stride=1):
        layers = []
        layers.append(ResidualBlock(in_channels, mid_channels, out_channels, stride=stride))
        for i in range(num_blocks - 1):
            layers.append(ResidualBlock(out_channels, mid_channels, out_channels))
        return nn.Sequential(*layers)
        
    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        
        x = nn.functional.avg_pool2d(x,8)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        
        return x

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels, mid_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(mid_channels)
        self.relu = nn.ReLU(inplace=True)
        
        self.conv2 = nn.Conv2d(mid_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
        if stride != 1 or in_channels != out_channels:
            self.downsample = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )
        else:
            self.downsample = nn.Identity()
        
    def forward(self, x):
        identity = x
        
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        
        out = self.conv2(out)
        out = self.bn2(out)
        
        identity = self.downsample(identity)
        
        out += identity
        out = self.relu(out)
        
        return out

# %% [markdown]
# Now, we instantiate the model

# %%
model = ResNet()

# %% [markdown]
# # Training the Model
#
# We first initialize parameters in PyTorch by creating a function that takes in a PyTorch module, checking what type of module it is, and then using the nn.init methods to actually initialize the parameters.
#
# We shall use He Normal initialization for the convolutional layers and Xavier Normal initialization for the fully connected layer. We shall also initialize the batch normalization layers with a scale factor of 1 and a bias term of 0.

# %% [markdown]
# We then define the loss function we want to use, the device we'll use and place our model and criterion on to our device.

# %%
lr = 0.1
optimizer = optim.SGD(model.parameters(), 
                      lr=lr, 
                      momentum=0.9, 
                      weight_decay=5e-4)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device == 'cuda':
    model = torch.nn.DataParallel(model)
    cudnn.benchmark = True
criterion = nn.CrossEntropyLoss()

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", factor=0.1, patience=15)

model = model.to(device)
criterion = criterion.to(device)

summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#             Conv2d-7           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-8           [-1, 64, 32, 32]             128
#           Identity-9           [-1, 64, 32, 32]               0
#              ReLU-10           [-1, 64, 32, 32]               0
#     ResidualBlock-11           [-1, 64, 32, 32]               0
#            Conv2d-12           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-13           [-1, 64, 32, 32]             128
#              ReLU-14           [-1, 64, 32, 32]               0
#            Conv2d-15           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-16           [-1, 64, 32, 32]             128
#          Identity-17           [-1, 64, 32, 32]               0
#              ReLU-18           [-1, 64, 32, 32]               0
#     ResidualBlock-19           [-1, 64, 32, 32]               0
#            Conv2d-20          [-1, 156, 16, 16]          89,856
#       BatchNorm2d-21          [-1, 156, 16, 16]             312
#              ReLU-22          [-1, 156, 16, 16]               0
#            Conv2d-23          [-1, 156, 16, 16]         219,024
#       BatchNorm2d-24          [-1, 156, 16, 16]             312
#            Conv2d-25          [-1, 156, 16, 16]           9,984
#       BatchNorm2d-26          [-1, 156, 16, 16]             312
#              ReLU-27          [-1, 156, 16, 16]               0
#     ResidualBlock-28          [-1, 156, 16, 16]               0
#            Conv2d-29          [-1, 156, 16, 16]         219,024
#       BatchNorm2d-30          [-1, 156, 16, 16]             312
#              ReLU-31          [-1, 156, 16, 16]               0
#            Conv2d-32          [-1, 156, 16, 16]         219,024
#       BatchNorm2d-33          [-1, 156, 16, 16]             312
#          Identity-34          [-1, 156, 16, 16]               0
#              ReLU-35          [-1, 156, 16, 16]               0
#     ResidualBlock-36          [-1, 156, 16, 16]               0
#            Conv2d-37            [-1, 220, 8, 8]         308,880
#       BatchNorm2d-38            [-1, 220, 8, 8]             440
#              ReLU-39            [-1, 220, 8, 8]               0
#            Conv2d-40            [-1, 220, 8, 8]         435,600
#       BatchNorm2d-41            [-1, 220, 8, 8]             440
#            Conv2d-42            [-1, 220, 8, 8]          34,320
#       BatchNorm2d-43            [-1, 220, 8, 8]             440
#              ReLU-44            [-1, 220, 8, 8]               0
#     ResidualBlock-45            [-1, 220, 8, 8]               0
#            Conv2d-46            [-1, 220, 8, 8]         435,600
#       BatchNorm2d-47            [-1, 220, 8, 8]             440
#              ReLU-48            [-1, 220, 8, 8]               0
#            Conv2d-49            [-1, 220, 8, 8]         435,600
#       BatchNorm2d-50            [-1, 220, 8, 8]             440
#          Identity-51            [-1, 220, 8, 8]               0
#              ReLU-52            [-1, 220, 8, 8]               0
#     ResidualBlock-53            [-1, 220, 8, 8]               0
#            Linear-54                   [-1, 10]           2,210
# ================================================================
# Total params: 2,562,706
# Trainable params: 2,562,706
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 16.51
# Params size (MB): 9.78
# Estimated Total Size (MB): 26.29
# ----------------------------------------------------------------

# %% [markdown]
# We define a function to calculate accuracy...

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %% [markdown]
# As we are using dropout we need to make sure to "turn it on" when training by using model.train()

# %%
def train(model, iterator, optimizer, criterion, device):
    epoch_loss = 0
    epoch_acc = 0
    model.train()
    for (x, y) in iterator:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()
        y_pred = model(x)
        loss = criterion(y_pred, y)
        acc = calculate_accuracy(y_pred, y)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# We also define an evaluation loop, making sure to "turn off" dropout with model.eval().

# %%
def evaluate(model, iterator, criterion, device):
    epoch_loss = 0
    epoch_acc = 0
    model.eval()
    with torch.no_grad():
        for (x, y) in iterator:
            x = x.to(device)
            y = y.to(device)
            y_pred = model(x)
            loss = criterion(y_pred, y)
            acc = calculate_accuracy(y_pred, y)
            epoch_loss += loss.item()
            epoch_acc += acc.item()
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# Next, we define a function to tell us how long an epoch takes.

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %% [markdown]
# Then, finally, we train our model.
#
# Train it for 50 epochs (using the train dataset). At the end of each epoch, compute the validation loss and keep track of the best model. You might find the command torch.save helpful.

# %%
N_EPOCHS = 100
best_valid_loss = float('inf')
lrs = []
train_loss_list,valid_loss_list  = [], []
train_acc_list, valid_acc_list = [], []
for epoch in range(N_EPOCHS):
    start_time = time.time()
    train_loss, train_acc = train(model, train_iterator, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, valid_iterator, criterion, device)
    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    lrs.append(optimizer.param_groups[0]['lr'])
    scheduler.step(valid_acc)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'best_model.pt')
    
    train_loss_list.append(train_loss)
    valid_loss_list.append(valid_loss)

    train_acc_list.append(train_acc)
    valid_acc_list.append(valid_acc)
    
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'Learning Rate {lrs[-1]:.3f}')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')
# Out:
# Epoch: 01 | Epoch Time: 0m 38s
# Learning Rate 0.100
# 	Train Loss: 1.692 | Train Acc: 36.96%
# 	 Val. Loss: 1.869 |  Val. Acc: 39.86%
# Epoch: 02 | Epoch Time: 0m 38s
# Learning Rate 0.100
# 	Train Loss: 1.266 | Train Acc: 53.74%
# 	 Val. Loss: 1.138 |  Val. Acc: 59.57%
# Epoch: 03 | Epoch Time: 0m 38s
# Learning Rate 0.100
# 	Train Loss: 1.042 | Train Acc: 62.59%
# 	 Val. Loss: 1.004 |  Val. Acc: 65.06%
# Epoch: 04 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.914 | Train Acc: 67.73%
# 	 Val. Loss: 0.877 |  Val. Acc: 70.55%
# Epoch: 05 | Epoch Time: 0m 38s
# Learning Rate 0.100
# 	Train Loss: 0.802 | Train Acc: 71.90%
# 	 Val. Loss: 0.761 |  Val. Acc: 73.87%
# Epoch: 06 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.710 | Train Acc: 75.28%
# 	 Val. Loss: 0.995 |  Val. Acc: 67.50%
# Epoch: 07 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.657 | Train Acc: 77.02%
# 	 Val. Loss: 0.795 |  Val. Acc: 72.36%
# Epoch: 08 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.618 | Train Acc: 78.45%
# 	 Val. Loss: 0.625 |  Val. Acc: 79.20%
# Epoch: 09 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.589 | Train Acc: 79.64%
# 	 Val. Loss: 0.897 |  Val. Acc: 70.74%
# Epoch: 10 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.565 | Train Acc: 80.56%
# 	 Val. Loss: 1.011 |  Val. Acc: 70.00%
# Epoch: 11 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.547 | Train Acc: 81.09%
# 	 Val. Loss: 0.581 |  Val. Acc: 81.35%
# Epoch: 12 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.522 | Train Acc: 82.00%
# 	 Val. Loss: 0.697 |  Val. Acc: 78.32%
# Epoch: 13 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.511 | Train Acc: 82.32%
# 	 Val. Loss: 0.618 |  Val. Acc: 79.00%
# Epoch: 14 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.508 | Train Acc: 82.27%
# 	 Val. Loss: 0.617 |  Val. Acc: 80.25%
# Epoch: 15 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.486 | Train Acc: 83.21%
# 	 Val. Loss: 0.592 |  Val. Acc: 80.68%
# Epoch: 16 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.488 | Train Acc: 83.11%
# 	 Val. Loss: 0.569 |  Val. Acc: 81.09%
# Epoch: 17 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.482 | Train Acc: 83.33%
# 	 Val. Loss: 0.594 |  Val. Acc: 79.34%
# Epoch: 18 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.467 | Train Acc: 83.77%
# 	 Val. Loss: 0.612 |  Val. Acc: 79.90%
# Epoch: 19 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.455 | Train Acc: 84.30%
# 	 Val. Loss: 0.517 |  Val. Acc: 83.67%
# Epoch: 20 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.455 | Train Acc: 84.29%
# 	 Val. Loss: 0.598 |  Val. Acc: 80.84%
# Epoch: 21 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.457 | Train Acc: 84.37%
# 	 Val. Loss: 0.551 |  Val. Acc: 81.54%
# Epoch: 22 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.446 | Train Acc: 84.61%
# 	 Val. Loss: 0.508 |  Val. Acc: 83.40%
# Epoch: 23 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.441 | Train Acc: 84.81%
# 	 Val. Loss: 0.760 |  Val. Acc: 76.13%
# Epoch: 24 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.440 | Train Acc: 84.92%
# 	 Val. Loss: 0.602 |  Val. Acc: 80.78%
# Epoch: 25 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.435 | Train Acc: 85.02%
# 	 Val. Loss: 0.615 |  Val. Acc: 80.12%
# Epoch: 26 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.437 | Train Acc: 84.98%
# 	 Val. Loss: 0.592 |  Val. Acc: 81.02%
# Epoch: 27 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.425 | Train Acc: 85.29%
# 	 Val. Loss: 0.570 |  Val. Acc: 81.43%
# Epoch: 28 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.432 | Train Acc: 85.13%
# 	 Val. Loss: 0.611 |  Val. Acc: 79.65%
# Epoch: 29 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.426 | Train Acc: 85.38%
# 	 Val. Loss: 0.570 |  Val. Acc: 81.93%
# Epoch: 30 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.436 | Train Acc: 84.86%
# 	 Val. Loss: 0.626 |  Val. Acc: 78.83%
# Epoch: 31 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.417 | Train Acc: 85.68%
# 	 Val. Loss: 0.429 |  Val. Acc: 85.74%
# Epoch: 32 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.411 | Train Acc: 85.85%
# 	 Val. Loss: 0.490 |  Val. Acc: 83.57%
# Epoch: 33 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.415 | Train Acc: 85.91%
# 	 Val. Loss: 0.580 |  Val. Acc: 81.74%
# Epoch: 34 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.410 | Train Acc: 85.89%
# 	 Val. Loss: 0.559 |  Val. Acc: 82.07%
# Epoch: 35 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.412 | Train Acc: 85.98%
# 	 Val. Loss: 0.656 |  Val. Acc: 79.57%
# Epoch: 36 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.404 | Train Acc: 85.96%
# 	 Val. Loss: 0.556 |  Val. Acc: 81.74%
# Epoch: 37 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.415 | Train Acc: 85.67%
# 	 Val. Loss: 0.556 |  Val. Acc: 81.99%
# Epoch: 38 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.407 | Train Acc: 85.81%
# 	 Val. Loss: 0.518 |  Val. Acc: 83.34%
# Epoch: 39 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.409 | Train Acc: 85.87%
# 	 Val. Loss: 0.518 |  Val. Acc: 83.09%
# Epoch: 40 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.405 | Train Acc: 86.10%
# 	 Val. Loss: 0.421 |  Val. Acc: 86.02%
# Epoch: 41 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.404 | Train Acc: 86.00%
# 	 Val. Loss: 0.503 |  Val. Acc: 83.79%
# Epoch: 42 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.397 | Train Acc: 86.17%
# 	 Val. Loss: 0.573 |  Val. Acc: 81.52%
# Epoch: 43 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.401 | Train Acc: 86.19%
# 	 Val. Loss: 0.523 |  Val. Acc: 83.11%
# Epoch: 44 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.400 | Train Acc: 86.06%
# 	 Val. Loss: 0.490 |  Val. Acc: 83.03%
# Epoch: 45 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.393 | Train Acc: 86.47%
# 	 Val. Loss: 0.503 |  Val. Acc: 83.52%
# Epoch: 46 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.396 | Train Acc: 86.22%
# 	 Val. Loss: 0.527 |  Val. Acc: 82.11%
# Epoch: 47 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.399 | Train Acc: 86.13%
# 	 Val. Loss: 0.659 |  Val. Acc: 79.39%
# Epoch: 48 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.395 | Train Acc: 86.60%
# 	 Val. Loss: 0.499 |  Val. Acc: 83.42%
# Epoch: 49 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.399 | Train Acc: 86.25%
# 	 Val. Loss: 0.500 |  Val. Acc: 83.22%
# Epoch: 50 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.394 | Train Acc: 86.46%
# 	 Val. Loss: 0.613 |  Val. Acc: 80.55%
# Epoch: 51 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.391 | Train Acc: 86.38%
# 	 Val. Loss: 0.594 |  Val. Acc: 82.23%
# Epoch: 52 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.386 | Train Acc: 86.58%
# 	 Val. Loss: 0.599 |  Val. Acc: 80.39%
# Epoch: 53 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.393 | Train Acc: 86.44%
# 	 Val. Loss: 0.573 |  Val. Acc: 81.43%
# Epoch: 54 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.393 | Train Acc: 86.44%
# 	 Val. Loss: 0.421 |  Val. Acc: 86.11%
# Epoch: 55 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.388 | Train Acc: 86.66%
# 	 Val. Loss: 0.434 |  Val. Acc: 85.64%
# Epoch: 56 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.389 | Train Acc: 86.50%
# 	 Val. Loss: 0.531 |  Val. Acc: 82.07%
# Epoch: 57 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.389 | Train Acc: 86.63%
# 	 Val. Loss: 0.732 |  Val. Acc: 77.85%
# Epoch: 58 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.394 | Train Acc: 86.36%
# 	 Val. Loss: 0.471 |  Val. Acc: 84.16%
# Epoch: 59 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.386 | Train Acc: 86.68%
# 	 Val. Loss: 0.564 |  Val. Acc: 81.91%
# Epoch: 60 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.388 | Train Acc: 86.45%
# 	 Val. Loss: 0.540 |  Val. Acc: 81.33%
# Epoch: 61 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.381 | Train Acc: 87.06%
# 	 Val. Loss: 0.513 |  Val. Acc: 83.05%
# Epoch: 62 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.383 | Train Acc: 86.92%
# 	 Val. Loss: 0.478 |  Val. Acc: 83.67%
# Epoch: 63 | Epoch Time: 0m 38s
# Learning Rate 0.100
# 	Train Loss: 0.387 | Train Acc: 86.69%
# 	 Val. Loss: 0.496 |  Val. Acc: 83.52%
# Epoch: 64 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.382 | Train Acc: 86.82%
# 	 Val. Loss: 0.531 |  Val. Acc: 83.79%
# Epoch: 65 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.387 | Train Acc: 86.68%
# 	 Val. Loss: 0.521 |  Val. Acc: 83.09%
# Epoch: 66 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.382 | Train Acc: 86.92%
# 	 Val. Loss: 0.500 |  Val. Acc: 84.16%
# Epoch: 67 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.384 | Train Acc: 86.66%
# 	 Val. Loss: 0.458 |  Val. Acc: 84.34%
# Epoch: 68 | Epoch Time: 0m 40s
# Learning Rate 0.100
# 	Train Loss: 0.385 | Train Acc: 86.63%
# 	 Val. Loss: 0.560 |  Val. Acc: 82.15%
# Epoch: 69 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.379 | Train Acc: 86.93%
# 	 Val. Loss: 0.538 |  Val. Acc: 82.83%
# Epoch: 70 | Epoch Time: 0m 39s
# Learning Rate 0.100
# 	Train Loss: 0.383 | Train Acc: 86.89%
# 	 Val. Loss: 0.649 |  Val. Acc: 79.61%
# Epoch: 71 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.230 | Train Acc: 92.36%
# 	 Val. Loss: 0.248 |  Val. Acc: 91.70%
# Epoch: 72 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.176 | Train Acc: 94.10%
# 	 Val. Loss: 0.227 |  Val. Acc: 92.29%
# Epoch: 73 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.157 | Train Acc: 94.70%
# 	 Val. Loss: 0.228 |  Val. Acc: 92.29%
# Epoch: 74 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.144 | Train Acc: 95.15%
# 	 Val. Loss: 0.222 |  Val. Acc: 92.56%
# Epoch: 75 | Epoch Time: 0m 40s
# Learning Rate 0.010
# 	Train Loss: 0.138 | Train Acc: 95.50%
# 	 Val. Loss: 0.230 |  Val. Acc: 92.36%
# Epoch: 76 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.127 | Train Acc: 95.75%
# 	 Val. Loss: 0.224 |  Val. Acc: 92.56%
# Epoch: 77 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.120 | Train Acc: 95.94%
# 	 Val. Loss: 0.217 |  Val. Acc: 92.75%
# Epoch: 78 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.114 | Train Acc: 96.14%
# 	 Val. Loss: 0.226 |  Val. Acc: 92.64%
# Epoch: 79 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.108 | Train Acc: 96.43%
# 	 Val. Loss: 0.221 |  Val. Acc: 92.79%
# Epoch: 80 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.103 | Train Acc: 96.57%
# 	 Val. Loss: 0.229 |  Val. Acc: 92.87%
# Epoch: 81 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.096 | Train Acc: 96.76%
# 	 Val. Loss: 0.224 |  Val. Acc: 92.83%
# Epoch: 82 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.093 | Train Acc: 96.86%
# 	 Val. Loss: 0.242 |  Val. Acc: 92.19%
# Epoch: 83 | Epoch Time: 0m 40s
# Learning Rate 0.010
# 	Train Loss: 0.089 | Train Acc: 97.10%
# 	 Val. Loss: 0.226 |  Val. Acc: 92.73%
# Epoch: 84 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.085 | Train Acc: 97.20%
# 	 Val. Loss: 0.220 |  Val. Acc: 93.48%
# Epoch: 85 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.085 | Train Acc: 97.18%
# 	 Val. Loss: 0.225 |  Val. Acc: 92.99%
# Epoch: 86 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.081 | Train Acc: 97.26%
# 	 Val. Loss: 0.221 |  Val. Acc: 93.05%
# Epoch: 87 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.079 | Train Acc: 97.39%
# 	 Val. Loss: 0.228 |  Val. Acc: 93.22%
# Epoch: 88 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.077 | Train Acc: 97.56%
# 	 Val. Loss: 0.227 |  Val. Acc: 92.91%
# Epoch: 89 | Epoch Time: 0m 40s
# Learning Rate 0.010
# 	Train Loss: 0.077 | Train Acc: 97.50%
# 	 Val. Loss: 0.244 |  Val. Acc: 92.50%
# Epoch: 90 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.073 | Train Acc: 97.64%
# 	 Val. Loss: 0.229 |  Val. Acc: 92.48%
# Epoch: 91 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.071 | Train Acc: 97.65%
# 	 Val. Loss: 0.248 |  Val. Acc: 91.86%
# Epoch: 92 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.072 | Train Acc: 97.59%
# 	 Val. Loss: 0.215 |  Val. Acc: 93.28%
# Epoch: 93 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.070 | Train Acc: 97.65%
# 	 Val. Loss: 0.250 |  Val. Acc: 92.48%
# Epoch: 94 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.072 | Train Acc: 97.70%
# 	 Val. Loss: 0.267 |  Val. Acc: 92.42%
# Epoch: 95 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.070 | Train Acc: 97.72%
# 	 Val. Loss: 0.242 |  Val. Acc: 92.40%
# Epoch: 96 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.071 | Train Acc: 97.71%
# 	 Val. Loss: 0.243 |  Val. Acc: 92.62%
# Epoch: 97 | Epoch Time: 0m 40s
# Learning Rate 0.010
# 	Train Loss: 0.067 | Train Acc: 97.80%
# 	 Val. Loss: 0.247 |  Val. Acc: 92.81%
# Epoch: 98 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.069 | Train Acc: 97.75%
# 	 Val. Loss: 0.262 |  Val. Acc: 92.89%
# Epoch: 99 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.071 | Train Acc: 97.67%
# 	 Val. Loss: 0.277 |  Val. Acc: 92.17%
# Epoch: 100 | Epoch Time: 0m 39s
# Learning Rate 0.010
# 	Train Loss: 0.070 | Train Acc: 97.70%
# 	 Val. Loss: 0.269 |  Val. Acc: 92.38%

# %% [markdown]
# # Evaluating the model
#
# We then load the parameters of our model that achieved the best validation loss.

# %%
model.load_state_dict(torch.load('best_model.pt'))
test_loss, test_acc = evaluate(model, test_iterator, criterion, device)
print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.223 | Test Acc: 93.06%

# %% [markdown]
# Printing the confusion matrix

# %%
def get_predictions(model, iterator, device):
    model.eval()
    labels = []
    probs = []
    with torch.no_grad():
      for (x, y) in iterator:
            x = x.to(device)
            y = y.to(device)
            y_pred = model(x)
            labels.append(y)
            probs.append(torch.softmax(y_pred, dim=1))
   
    labels = torch.cat(labels, dim = 0)
    probs = torch.cat(probs, dim = 0)

    return labels, probs

# %%
labels, probs = get_predictions(model, test_iterator, device)
pred_labels = torch.argmax(probs, 1)

# %%
def plot_confusion_matrix(labels, pred_labels, classes):
    
    labels = labels.cpu().numpy()
    pred_labels = pred_labels.cpu().numpy()

    fig = plt.figure(figsize = (10, 10));
    ax = fig.add_subplot(1, 1, 1);
    cm = confusion_matrix(labels, pred_labels);
    cm = ConfusionMatrixDisplay(cm, display_labels = classes);
    cm.plot(values_format = 'd', cmap = 'Blues', ax = ax)
    plt.xticks(rotation = 20)
    plt.show()

# %%
plot_confusion_matrix(labels, pred_labels, classes)

# %%
import numpy as np
xax = range(N_EPOCHS)

# Loss Curve
fig, axs = plt.subplots(1, 2, figsize=(9,3))
axs[0].plot(xax, train_loss_list, label="Training Loss")
axs[0].plot(xax, valid_loss_list, label="Validation Loss")
axs[0].set_title('Loss curve plot', fontsize=10)

axs[0].set_xlabel('epoch')
axs[0].set_ylabel('loss')
axs[0].grid()
axs[0].legend(loc="center right", fontsize=7)
axs[0].pcolorfast(xax, axs[0].get_ylim(), np.log(np.array(lrs))[np.newaxis], cmap="hot", alpha=0.4, vmax=np.log(1e-1), vmin=np.log(1e-4))

for j in range(1,N_EPOCHS-1):
    if lrs[j] != lrs[j-1]:
        axs[0].text(j+0.5, axs[0].get_ylim()[1]-0.0005, f"lr={round(lrs[j],6)}", fontsize=8, va="top")

# Accuracy Curve
axs[1].plot(xax, train_acc_list, label="Train Acc")
axs[1].plot(xax, valid_acc_list, label="Test Acc")
best_epoch, best_val = np.argmax(train_acc_list), max(train_acc_list)
axs[1].scatter(best_epoch, best_val, marker="o", c="violet")
axs[1].text(best_epoch, best_val, round(best_val, 2), va="top", ha="center", fontsize=7)
axs[1].set_title('Accuracy curve', fontsize=10)
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('acc')
axs[1].grid()
axs[1].legend(loc="center right", fontsize=8)
axs[1].pcolorfast(xax, axs[1].get_ylim(), np.log(np.array(lrs))[np.newaxis], cmap="hot", alpha=0.3, vmax=np.log(1e-1), vmin=np.log(1e-4))

for j in range(1,N_EPOCHS-1):
    if lrs[j] != lrs[j-1]:
        axs[1].text(j+0.5, axs[1].get_ylim()[0]-0.0005, f"lr={round(lrs[j],6)}", fontsize=8, va="bottom")

fig.tight_layout()
fig.suptitle("Shallower Network")
fig.show()
